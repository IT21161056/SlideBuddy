# %%
import streamlit as st
import google.generativeai as genai

# %%
# Configure API Key
genai.configure(api_key="your-api-key-here")

# Initialize model
model = genai.GenerativeModel("gemini-1.5-pro")

# Session state for chat history
if "history" not in st.session_state:
    st.session_state.history = []

st.title("💬 Gemini Chatbot")
st.markdown("Ask me anything!")

# User input
user_input = st.text_input("You:", "")

if st.button("Send") and user_input:
    # Add user message to history
    st.session_state.history.append({"role": "user", "parts": [user_input]})

    # Send full history to Gemini
    response = model.generate_content(st.session_state.history)

    # Add bot response to history
    st.session_state.history.append({"role": "model", "parts": [response.text]})

    # Display conversation
    for message in st.session_state.history:
        if message["role"] == "user":
            st.markdown(f"**You:** {message['parts'][0]}")
        else:
            st.markdown(f"**Bot:** {message['parts'][0]}")
# Out:
# 2025-04-25 23:18:09.573 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.576 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2025-04-25 23:18:09.578 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.579 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.582 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.815
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\projects\CTSE\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-25 23:18:09.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 23:18:09.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run notebook.ipynb
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Streamlit requires raw Python (.py) files, not .ipynb.
# For more information, please see https://docs.streamlit.io
